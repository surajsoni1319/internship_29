# %% [markdown]
# ### 1. Write a python program which searches all the product under a particular product from www.amazon.in. The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup
import requests

# Importing selenium webdriver 
from selenium import webdriver
from selenium.webdriver.common.by import By

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementClickInterceptedException

# importing regex
import re

#Importing Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# connect to webdriver
driver = webdriver.Chrome("chromedriver.exe")

# get webpage
driver.get("https://www.amazon.in/")
driver.maximize_window()
time.sleep(2)

# %%
# search the user input product
search_bar = driver.find_element(By.ID,"twotabsearchtextbox")    
search_bar.clear()                                               
search_bar.send_keys(input('Enter the product you want to search : '))
time.sleep(3)
driver.find_element(By.XPATH,'//div[@class="nav-search-submit nav-sprite"]/span/input').click()
# Out:
# Enter the product you want to search : LAPTOP

# %% [markdown]
# ### 2. In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product has less than 3 pages in search results then scrape all the products available under that product name. Details to be scraped are: "Brand Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# b_name=[]#Brand name
product_name=[]#Product Name
price=[]#Price
ret_exchange=[]#return/Exchange
exp_delivery=[]#Expected delivery
availability=[]#Availability
product_url=[]
urls=[]
for i in range(0,3):
    if i==0:
        p_urls=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a")
    if i==1:
        n_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[28]/div/div/span/a[2]')
        n_button.click()
        time.sleep(2)
        p_urls=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a")
   
    # selecting and clicking next page
    if i==2:
        n_button=driver.find_element(By.XPATH,'/html/body/div[1]/div[2]/div[1]/div[1]/div/span[3]/div[2]/div[29]/div/div/span/a[3]')
        n_button.click()
        time.sleep(2)
        p_urls=driver.find_elements(By.XPATH,"//h2[@class='a-size-mini a-spacing-none a-color-base s-line-clamp-2']/a")
            
            

    for i in p_urls:
        urls.append(i.get_attribute('href'))

    
for i in urls:
    driver.get(i)
    time.sleep(2)
#scraping data for brand name
    try:
        bran=driver.find_element(By.XPATH,"//a[@id='bylineInfo']")
        b_name.append(bran.text)
    except NoSuchElementException as e:
        b_name.append("--")

#scraping data for product name
    try:
        prod=driver.find_element(By.XPATH,"//h1[@id='title']/span")
        product_name.append(prod.text)
    except NoSuchElementException as e:
        product_name.append("--")


#scraping data for price
    try:
        pri=driver.find_element(By.XPATH,"//div[@id='apex_desktop']/div/div/table/tbody/tr[2]/td[2]/span/span[2]")
        price.append(pri.text)
    except NoSuchElementException as e:
            price.append("--")

#scaping data for return
    try:
        retu=driver.find_element(By.XPATH,"//div[@id='RETURNS_POLICY']/span/div[2]/a")
        ret_exchange.append(retu.text)
    except NoSuchElementException as e:
        ret_exchange.append("--")

#scraping data for expected delivery
    try:
        deliv=driver.find_element(By.XPATH,"//div[@id='ddmDeliveryMessage']/b")
        exp_delivery.append(deliv.text)
    except NoSuchElementException as e:
        exp_delivery.append("--")

#scraping data for availability
    try:
        avail=driver.find_element(By.XPATH,"//div[@id='availability']/span")
        availability.append(avail.text)
    except NoSuchElementException as e:
        availability.append("--")

# %%
print(len(availability),len(b_name),len(product_name),len(ret_exchange),len(exp_delivery),len(availability),len(price),len(urls))
# Out:
# 69 69 69 69 69 69 69 69

# %%
#creatig dataframe
df=pd.DataFrame({"Brand Name":b_name,"Product":product_name,"Price":price,"Return/Exchange":ret_exchange,"Expected Delivery":exp_delivery,"Availability":availability})#"Product Url":urls})
df
# Out:
#                 Brand Name                                            Product  \
# 0     Visit the Acer Store  Acer Aspire 3 Laptop Intel Core i5 11th Gen - ...
# 1     Visit the Acer Store  Acer Travelmate Business Laptop Intel Corei3 1...
# 2       Visit the HP Store  HP 15s- Ryzen 5- 8GB RAM/512GB SSD 15.6 Inches...
# 3   Visit the Lenovo Store  Lenovo IdeaPad Slim 3 Intel Core i3 11th Gen 1...
# 4   Visit the Lenovo Store  Lenovo Ideapad 3 AMD Ryzen 5 5500U 15.6" (39.6...
# ..                     ...                                                ...
# 64      Visit the HP Store  HP 15- AMD Ryzen 3-3250U 15.6 inch(39.6 cm) FH...
# 65      Visit the HP Store  HP 245 G8 AMD Ryzen 5 - 3500U 14 inch Laptop (...
# 66      Visit the HP Store  HP 245 G8 AMD Ryzen 3 - 3300U 14 inches Busine...
# 67     Visit the MSI Store  MSI Modern 14, Intel i5-10210U, 14"(35cm) FHD ...
# 68      Visit the LG Store  LG Gram 17 Intel Evo 11th Gen i5 Thin & Light ...
#
#          Price     Return/Exchange Expected Delivery           Availability
# 0           --  7 Days Replacement                --              In stock.
# 1           --  7 Days Replacement                --              In stock.
# 2           --  7 Days Replacement                --              In stock.
# 3           --  7 Days Replacement                --              In stock.
# 4           --  7 Days Replacement                --              In stock.
# ..         ...                 ...               ...                    ...
# 64  ₹37,990.00  7 Days Replacement                --              In stock.
# 65          --  7 Days Replacement                --              In stock.
# 66          --  7 Days Replacement                --
# 67          --  7 Days Replacement                --              In stock.
# 68          --  7 Days Replacement                --  Only 1 left in stock.
#
# [69 rows x 6 columns]

# %%
df.to_csv("Scraped File",index=False)

# %%
driver.close()

# %% [markdown]
# ## 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()
driver.get('https://images.google.com/')

inp = ['fruits','cars','Machine Learning','Guitar','Cakes'] # input list

#Creating Empty lists
fruits=[]
cars=[]
ML=[]
Guitar=[]
Cakes=[]

lists = [] # list of empty lists

for i in inp:
    try:
        search_bar=driver.find_element(By.XPATH,'//*[@id="sbtc"]/div/div[2]/input') # Finding the search bar using it's xpath
    except NoSuchElementException:
        search_bar=driver.find_element(By.XPATH,'//input[@class="og3lId"]') # Finding the search bar using it's xpath
        
    search_bar.clear()
    search_bar.send_keys(i) # Inputing input keyword to search rock images
    
    try:
        button=driver.find_element(By.XPATH,'//*[@id="sbtc"]/button')  
    except NoSuchElementException:
        button=driver.find_element(By.XPATH,'//button[@class="rCGXm"]')
    button.click()
    
    
    img = driver.find_elements(By.XPATH,'//div[@class="bRMDJf islir"]/img')
    for k in img:
        try:
            source= k.get_attribute('src')
            if source is not None:
                if (source[0:4]=="http"):
                    lists.append(source)
        except NoSuchElementException:
            lists.append('-')
            

len(lists)            
#print(len(fruits),len(cars),len(ML),len(Guitar),len(Cakes))
# Out:
# 135

# %%
fruits=lists[1:21]
cars=lists[22:42]
ML=lists[43:63]
Guitar=lists[64:84]
Cakes=lists[85:105]

print(len(fruits),len(cars),len(ML),len(Guitar),len(Cakes))
# Out:
# 20 20 20 20 20

# %%
#creating a dataframe
df=pd.DataFrame({'Fruits':fruits,
                 'Cars':cars,
                 'Machine Learning':ML,
                 'Guitar':Guitar,
                 'Cakes':Cakes})

#printing dataframe
df.head()
# Out:
#                                               Fruits  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                                 Cars  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                     Machine Learning  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                               Guitar  \
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...
#
#                                                Cakes
# 0  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 1  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 2  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 3  https://encrypted-tbn0.gstatic.com/images?q=tb...
# 4  https://encrypted-tbn0.gstatic.com/images?q=tb...

# %% [markdown]
# ## 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
# Connecting to webdriver
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

# opening the url
driver.get('https://www.flipkart.com')

#cancelling login window
search_btn = driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _2doB4z"]')
search_btn.click()

# getting the input
search_inp = input("Enter the product: ")

# locating the search bar
search_bar = driver.find_element(By.XPATH,"//input[@class='_3704LK']")
search_bar.send_keys(search_inp)

# locating the search button
search_btn = driver.find_element(By.XPATH,'//button[@class="L0Z3Pu"]')
search_btn.click()
# Out:
# Enter the product: pixel 4A

# %%
# creating Empty variable to store our data:
brand = []
s_name = []
color = []
ram = []
rom = []
p_camera = []
s_camera = []
display_s = []
display_r = []
battery = []
price = []
url = []

# %%
# fetching the details

# extracting product name, brand name, colour.
for i in driver.find_elements(By.XPATH,"//div[@class='_4rR01T']"):
    s_name.append(i.text)
    name = s_name[-1].split() #extracting the brand name from the product name
    brand.append(name[0])
    a = s_name[-1][s_name[-1].find("(")+1:s_name[-1].rfind(")")]
    color.append(a.split(',')[0]) #extracting colour from the product name
    
# extracting the ram and rom.
for j in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[1]"):
    ram.append(j.text.split('|')[0])
    rom.append(j.text.split('|')[1])
    
# extracting primary and secondary camera
for k in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[3]"):
    if(len(k.text.split('|')) == 2):
        p_camera.append(k.text.split('|')[0])
        s_camera.append(k.text.split('|')[1])
    else:
        p_camera.append(k.text.split('|')[0])
        s_camera.append('--')

# extracting display size and display resolution
for l in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[2]"):
    s = l.text[l.text.find("(")+1:l.text.rfind(")")]
    display_s.append(s)
    r = l.text[l.text.find(")")+1:]
    display_r.append(r)
        
#extracting battery power.
for n in driver.find_elements(By.XPATH,"//ul[@class='_1xgFaf']/li[4]"):
    battery.append(n.text)
    
# extracting price
for o in driver.find_elements(By.XPATH,"//div[@class='_30jeq3 _1_WHN1']"):
    price.append(o.text)

# extracting url
for p in driver.find_elements(By.XPATH,"//a[@class='_1fQZEK']"):
    url.append(p.get_attribute('href'))

# %%
flipkart = pd.DataFrame({})
flipkart['Brand'] = brand
flipkart['Product description'] = s_name
flipkart['Colour'] = color
flipkart['RAM'] = ram
flipkart['ROM'] = rom
flipkart['Primary Camera'] = p_camera
flipkart['Secondary Camera'] = s_camera
flipkart['Display Size'] = display_s
flipkart['Display Resolution'] = display_r
flipkart['Battery'] = battery
flipkart['Price'] = price
flipkart['Product url'] = url

# %%
flipkart.head()
# Out:
#     Brand                    Product description           Colour        RAM  \
# 0  Google   Google Pixel 4a (Just Black, 128 GB)       Just Black  6 GB RAM
# 1    vivo         vivo T1 44W (Ice Dawn, 128 GB)         Ice Dawn  4 GB RAM
# 2    vivo       vivo T1 44W (Starry Sky, 128 GB)       Starry Sky  6 GB RAM
# 3    vivo       vivo T1 44W (Starry Sky, 128 GB)       Starry Sky  4 GB RAM
# 4    vivo  vivo T1 44W (Midnight Galaxy, 128 GB)  Midnight Galaxy  4 GB RAM
#
#             ROM       Primary Camera    Secondary Camera Display Size  \
# 0    128 GB ROM  12.2MP Rear Camera     8MP Front Camera    5.81 inch
# 1   128 GB ROM     50MP + 2MP + 2MP    16MP Front Camera    6.44 inch
# 2   128 GB ROM     50MP + 2MP + 2MP    16MP Front Camera    6.44 inch
# 3   128 GB ROM     50MP + 2MP + 2MP    16MP Front Camera    6.44 inch
# 4   128 GB ROM     50MP + 2MP + 2MP    16MP Front Camera    6.44 inch
#
#          Display Resolution                   Battery    Price  \
# 0          Full HD+ Display          3140 mAh Battery  ₹31,999
# 1   Full HD+ AMOLED Display  5000 mAh Lithium Battery  ₹14,499
# 2   Full HD+ AMOLED Display  5000 mAh Lithium Battery  ₹15,999
# 3   Full HD+ AMOLED Display  5000 mAh Lithium Battery  ₹14,499
# 4   Full HD+ AMOLED Display  5000 mAh Lithium Battery  ₹14,499
#
#                                          Product url
# 0  https://www.flipkart.com/google-pixel-4a-just-...
# 1  https://www.flipkart.com/vivo-t1-44w-ice-dawn-...
# 2  https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 3  https://www.flipkart.com/vivo-t1-44w-starry-sk...
# 4  https://www.flipkart.com/vivo-t1-44w-midnight-...

# %%
flipkart.to_csv("Scraped mobile File",index=False)

# %%
driver.close()

# %% [markdown]
# ### 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
# Importing libraries
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re

# Importing warings
import warnings
warnings.filterwarnings('ignore')

# %%
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

# opening the url
driver.get('https://www.google.com/maps')

search_inp = input("Enter the city: ")
search_bar = driver.find_element(By.XPATH,"//input[@id='searchboxinput']") # locating search bar
search_bar.send_keys(search_inp)

# locating search button
search_btn = driver.find_element(By.XPATH,"//button[@id='searchbox-searchbutton']")
search_btn.click()

# getting the geospatial co-ordinates from the url
time.sleep(2)
geo = driver.current_url
r = geo[geo.find("@")+1:]
s = r[0:21]
s = s.split(',')
print(f'''Latitude: {s[0]}
Longitude: {s[1]}''')
# Out:
# Enter the city: ranchi
# Latitude: 25.6170142
# Longitude: 85.1168048

# %% [markdown]
# ## 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
#importing required libraries:

# Importing libraries
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re

# %%
driver = webdriver.Chrome("chromedriver.exe")

# get webpage
driver.get("https://trak.in/")
time.sleep(2)
driver.maximize_window()

# %%
#click on funding deals and go to that page
fun_btn=driver.find_element(By.XPATH,"//li[@id='menu-item-51510']/a").get_attribute('href')
driver.get(fun_btn)

# %%
# Creating empty list
funding={}
funding["Date"]=[]
funding["Startup Name"]=[]
funding["Industry or Vertical"]=[]
funding["Sub Vertical"]=[]
funding["Location"]=[]
funding["Investor"]=[]
funding["Investment Type"]=[]
funding["Amount"]=[]

for i in range(54,57):


    # Scraping data of Date
    date_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))# {} and .format () used
    #so the number coming in function format(n) will replace {}
    for date in date_tags:
        funding['Date'].append(date.text)

    # Scraping data of Startup Name
    name_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for name in name_tags:
        funding['Startup Name'].append(name.text)
    
    # Scraping data of Industry OR Vertical
    ind_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind_tags:
        funding['Industry or Vertical'].append(n.text)
    
    # Scraping data of Sub-Vertical
    sv_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for sv in sv_tags:
        funding['Sub Vertical'].append(sv.text)

    # Scraping data of Location
    loc_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for loc in loc_tags:
        funding['Location'].append(loc.text)
    
    # Scraping data of Investor
    inv_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for inv in inv_tags:
        funding['Investor'].append(inv.text)
        
    # Scraping data of Investment Type
    invt_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for invt in invt_tags:
        funding['Investment Type'].append(invt.text)
    # Scraping data of Amount
    amt_tags = driver.find_elements(By.XPATH,'//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for amt in amt_tags:
        funding['Amount'].append(amt.text)

# %%
details=pd.DataFrame(funding)
details.head()
# Out:
#          Date            Startup Name    Industry or Vertical  \
# 0  15/01/2021         Digit Insurance      Financial Services
# 1  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2  19/01/2021                  DeHaat        AgriTech Startup
# 3  19/01/2021               Darwinbox                    SaaS
# 4  18/01/2021                   mfine     Health Tech Startup
#
#                                         Sub Vertical   Location  \
# 0                                 Insurance Services  Bengaluru
# 1      Shave care, beard care, and skincare products  New Delhi
# 2  online marketplace for farm products and services      Patna
# 3                                            HR Tech     Mumbai
# 4                 AI-powered telemedicine mobile app  Bengaluru
#
#                                            Investor Investment Type  \
# 0  A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                 Reckitt Benckiser         Venture
# 2                                   Prosus Ventures        Series C
# 3                               Salesforce Ventures            Seed
# 4                        Heritas Capital Management   Venture Round
#
#          Amount
# 0   1,80,00,000
# 1  6,172,258.50
# 2    30,000,000
# 3    15,000,000
# 4    16,000,000

# %% [markdown]
# ## 7. Write a program to scrap all the available details of best gaming laptops from digit.in.

# %%
driver=webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

driver.get("https://www.digit.in/")

# %%
driver.find_element(By.XPATH,"//div[@class='listing_container']//ul//li[9]").click()
time.sleep(3)

# %%
#Creating empty lists
Laptop_Name = []
Operating_sys = []
Display = []
Processor = []
Memory = []
Weight = []
Dimensions = []
Graph_proc = []
Price = []
# Scraping the data of laptop names
laptop_name= driver.find_elements(By.XPATH,"//div[@class='right-container']/div/a/h3")
for name in laptop_name:
    Laptop_Name.append(name.text)
    
    
#Scraping the data of operating system
try:
    op_sys = driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[1]/div/div")
    for os in op_sys:
        Operating_sys.append(os.text)
except NoSuchElementException:
    pass


#Scraping data of display of the laptop
try:
    display= driver.find_elements(By.XPATH,"//div[@class='product-detail']/div/ul/li[2]/div/div")
    for disp in display:
        Display.append(disp.text)
except NoSuchElementException:
    pass


#Scraping data of Processor
try:
    processor = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[5]/td[3]")
    for pro in processor:
        Processor.append(pro.text)
except NoSuchElementException:
    pass

#Scraping data of memory
try:
    memory = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")
    for memo in memory:
        Memory.append(memo.text)
except NoSuchElementException:
    pass



#Scraping data of dimensions
try:
    dimension = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[8]/td[3]")
    for dim in dimension:
        Dimensions.append(dim.text)
except NoSuchElementException:
    pass


#Scraping data of Graph processor
try:
    graph = driver.find_elements(By.XPATH,"//div[@class='Spcs-details'][1]/table/tbody/tr[7]/td[3]")
    for gra in graph:
        Graph_proc.append(gra.text)
except NoSuchElementException:
    pass


#Scraping data of price
try:
    price = driver.find_elements(By.XPATH,"//td[@class='smprice']")
    for pri in price:
        Price.append(pri.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# %%
print(len(Laptop_Name),len(Operating_sys),len(Display),len(Processor),len(Memory),len(Dimensions),len(Graph_proc),len(Price))
# Out:
# 10 10 10 10 10 10 10 10

# %%
Gaming_Laptop=pd.DataFrame({})
Gaming_Laptop['Laptop Name'] = Laptop_Name
Gaming_Laptop['Operating system'] = Operating_sys
Gaming_Laptop['Display'] = Display
Gaming_Laptop['Processor'] = Processor
Gaming_Laptop['Memory'] = Memory
Gaming_Laptop['Dimensions'] = Dimensions
Gaming_Laptop['Graphical Processor'] = Graph_proc
Gaming_Laptop['Price'] = Price
Gaming_Laptop
# Out:
#                                      Laptop Name    Operating system  \
# 0                           MSI TITAN GT77-12UHS  WINDOWS 11 HOME OS
# 1                               ALIENWARE X17 R2  WINDOWS 11 HOME OS
# 2          ACER PREDATOR TRITON 500 SE PT516-52S  WINDOWS 11 HOME OS
# 3                        OMEN BY HP (16-B1371TX)  WINDOWS 11 HOME OS
# 4  ACER PREDATOR HELIOS 300 AN515-45 (NH.QBRSI.0  WINDOWS 11 HOME OS
# 5                     MSI DELTA 15 (A5EFK-083IN)  WINDOWS 11 HOME OS
# 6                        OMEN BY HP (16-C0141AX)  WINDOWS 11 HOME OS
# 7              LENOVO LEGION 5I PRO (82RF00MGIN)  WINDOWS 11 HOME OS
# 8  ALIENWARE M15 R5 RYZEN EDITION ICC-C780001WIN  WINDOWS 11 HOME OS
# 9               LENOVO SLIM 7 GEN 6 (82K8002JIN)  WINDOWS 11 HOME OS
#
#                        Display        Processor                       Memory  \
# 0  17.3" (3840 X 2160) DISPLAY  Windows 11 Home    64 GB DDR5 RAM & 2 TB SSD
# 1    17.3" (1920X1080) DISPLAY  Windows 11 Home    32 GB DDR5 RAM & 1 TB SSD
# 2    16" (2560 X 1600) DISPLAY  Windows 11 Home    32 GB DDR5 RAM & 2 TB SSD
# 3  16.1" (2560 X 1440) DISPLAY  Windows 11 Home     8 GB DDR5 RAM & 1 TB SSD
# 4  15.6" (2560 X 1440) DISPLAY  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 5  15.6" (1920 X 1080) DISPLAY  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
# 6  16.1" (2560 X 1440) DISPLAY  Windows 11 Home   16 GB DDR4 RAM & 1 TB NVMe
# 7    16" (2560 X 1600) DISPLAY  Windows 11 Home    16 GB DDR5 RAM & 1 TB SSD
# 8  15.6" (1920 X 1080) DISPLAY  Windows 11 Home  16 GB DDR4 RAM & 512 GB SSD
# 9         15.6 MP | NA DISPLAY  Windows 11 Home    16 GB DDR4 RAM & 1 TB SSD
#
#                                           Dimensions  \
# 0        397 x 330 x 23 mm dimension & 3.3 kg weight
# 1  399.23 x 299.57 x 14.75 mm dimension & 3.02 kg...
# 2      358 x 262 x 19.9 mm dimension & 2.4 kg weight
# 3       369 x 248 x 23 mm dimension & 2.32 kg weight
# 4      363 x 255 x 23.9 mm dimension & 2.4 kg weight
# 5        357 x 247 x 19 mm dimension & 1.9 kg weight
# 6    36.92 x 24.8 x 2.3 mm dimension & 2.3 kg weight
# 7  359.9 x 264.4 x 19.9 mm dimension & 2.5 kg weight
# 8  356.2 x 272.5 x 22.85 mm dimension & 2.69 kg w...
# 9        356 x 252 x 16 mm dimension & 1.9 kg weight
#
#                                  Graphical Processor        Price
# 0  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti Graphics...          N/A
# 1  16 GB DDR6 NVIDIA GeForce RTX 3080 Ti, Graphic...  Rs  389,990
# 2  8 GB DDR6 NVIDIA GeForce RTXTM 3070 Ti Graphic...  Rs  300,000
# 3   8 GB GDDR6 NVIDIA GeForce RTX 3070 Graphics card  Rs  170,990
# 4    8 GB DDR6 NVIDIA GeForce RTX 3070 Graphics card  Rs  172,999
# 5       10 GB DDR6 AMD Radeon RX 6700M Graphics card  Rs  188,990
# 6      8 GB GDDR6 AMD Radeon™ RX 6600M Graphics card  Rs  129,899
# 7    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card  Rs  230,890
# 8    6 GB DDR6 NVIDIA GeForce RTX 3060 Graphics card  Rs  144,990
# 9  6 GB DDR6 NVIDIA GeForce 3060 Max-Q Graphics card  Rs  142,990

# %% [markdown]
# ### 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
# Connecting to webdriver
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

# opening the url
driver.get('https://www.forbes.com/')

# clicking on options
driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/button[1]').click()

# %%
#clickng on All Billionaires option 

billionaires=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[3]/ul/li[1]')
billionaires.click()

all_billionaires=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')
all_billionaires.click()

# %%
# Scrapping required details:

#creating empty lists:
Rank = []
Name = []
Net_Worth = []
Age = []
Citizenship = []
Source = []
Industry = []

# Scraping Ranks

try:
    R = driver.find_elements(By.XPATH,'//div[@class="rank"]')
    for i in R:
        Rank.append(i.text)
except NoSuchElementException:
    Rank.append("-")

#Scraping Names
try:
    N = driver.find_elements(By.XPATH,'//div[@class="personName"]')
    for i in N:
        Name.append(i.text)
except NoSuchElementException:
    Name.append("-")

#Scraping Net Worth
try:
    NW = driver.find_elements(By.XPATH,'//div[@class="netWorth"]')
    for i in NW:
        Net_Worth.append(i.text)
except NoSuchElementException:
    Net_Worth.append("-")
    
#Scraping Age
try:
    A = driver.find_elements(By.XPATH,'//div[@class="age"]')
    for i in A:
        Age.append(i.text)
except NoSuchElementException:
    Age.append("-")

#Scraping country Of Citizenship
try:
    C = driver.find_elements(By.XPATH,'//div[@class="countryOfCitizenship"]')
    for i in C:
        Citizenship.append(i.text)
except NoSuchElementException:
    Citizenship.append("-")
    
#Scraping Source
try:
    S = driver.find_elements(By.XPATH,'//div[@class="source"]')
    for i in S:
        Source.append(i.text)
except NoSuchElementException:
    Source.append("-")

#Scraping Industry
try:
    I = driver.find_elements(By.XPATH,'//div[@class="category"]')
    for i in I:
        Industry.append(i.text)
except NoSuchElementException:
    Industry.append("-")

# %%
print(len(Rank),len(Name),len(Net_Worth),len(Age),len(Citizenship),len(Source),len(Industry))
# Out:
# 200 200 200 200 200 200 200

# %%
df = pd.DataFrame({'Rank':Rank,
                   'Name':Name,
                   'Net_Worth':Net_Worth,
                   'Age':Age,
                   'Citizenship':Citizenship,
                   'Source':Source,
                   'Industry':Industry})
df
# Out:
#      Rank                      Name Net_Worth Age    Citizenship  \
# 0      1.                 Elon Musk    $219 B  50  United States
# 1      2.                Jeff Bezos    $171 B  58  United States
# 2      3.  Bernard Arnault & family    $158 B  73         France
# 3      4.                Bill Gates    $129 B  66  United States
# 4      5.            Warren Buffett    $118 B  91  United States
# ..    ...                       ...       ...  ..            ...
# 195  192.    Marcel Herrmann Telles   $10.3 B  72         Brazil
# 196  197.                Leon Black     $10 B  70  United States
# 197  197.                Joe Gebbia     $10 B  40  United States
# 198  197.              David Geffen     $10 B  79  United States
# 199  197.                Yu Renrong     $10 B  56          China
#
#                     Source               Industry
# 0            Tesla, SpaceX             Automotive
# 1                   Amazon             Technology
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4       Berkshire Hathaway  Finance & Investments
# ..                     ...                    ...
# 195                   beer        Food & Beverage
# 196         private equity  Finance & Investments
# 197                 Airbnb             Technology
# 198  movies, record labels  Media & Entertainment
# 199         semiconductors          Manufacturing
#
# [200 rows x 7 columns]

# %%
driver.close()

# %% [markdown]
# ### 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
# Importing libraries
import pandas as pd
import selenium
import time
from bs4 import BeautifulSoup 
from selenium import webdriver
from selenium.webdriver.common.by import By

from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import requests
import re

# %%
# Connecting to webdriver
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

# opening the url
driver.get('https://www.youtube.com/')

# Clicking on any Random Video
driver.find_element(By.XPATH,'/html/body/ytd-app/div/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[6]/ytd-rich-grid-row[2]/div/ytd-rich-item-renderer[2]/div/ytd-rich-grid-media/div[1]/div[2]').click()

# %%
# Pausing the video
driver.find_element(By.XPATH,'/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[5]/div[1]/div/div[1]').click()

# %%
# Scrapping required details:

#Creating Empty Lists
Comment = []
Upvote = []
Time = []

# Scraping Comments 
C = driver.find_elements(By.ID,"content-text")
for i in C:
    Comment.append(i.text)
    
#Scrapping Upvotes
try:
    U = driver.find_elements(By.XPATH,'//span[@id="vote-count-middle"]')
    for i in U:
        Upvote.append(i.text)
except NoSuchElementException:
    Upvote.append("-")

#Scrapping when comment was posted 
try:
    T = driver.find_elements(By.XPATH,'//a[@class="yt-simple-endpoint style-scope yt-formatted-string"]')
    for i in T:
        Time.append(i.text)
except NoSuchElementException:
    Time.append("-")

# %%
print(len(Comment),len(Upvote),len(Time))
# Out:
# 410 430 518

# %%
df = pd.DataFrame({'Comments':Comment[:410],
                   'Comment upvote':Upvote[:410],
                   'time when comment was posted':Time[:410]})

df
# Out:
#                                               Comments Comment upvote  \
# 0    Thank you so much for the love everyone .. I'm...            62K
# 1    you deserve all this praise armaan!  you're a ...            692
# 2                                       Superb work <3            211
# 3       +Armaan Malik Your voice gave soul to this. :)            244
# 4    ohh man its simply awesome really \nso sweet t...            115
# ..                                                 ...            ...
# 405  Really heart touching song ️ love from odisha ...              6
# 406  That feeling when words come to your heart but...              3
# 407  I am here only for my love whenever someone li...              1
# 408  i dont know why i heard this song it still rem...
# 409  Not all love stories are "Rab ne bana do jodi"...            631
#
#     time when comment was posted
# 0
# 1
# 2
# 3
# 4
# ..                           ...
# 405                  1 month ago
# 406                  3 weeks ago
# 407               54 minutes ago
# 408                  1 month ago
# 409                   1 year ago
#
# [410 rows x 3 columns]

# %%
driver.close()

# %% [markdown]
# ### 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description.

# %%
# Connecting to webdriver
driver = webdriver.Chrome("chromedriver.exe")
driver.maximize_window()

# opening the url
driver.get('https://www.hostelworld.com/')

# %%
# Enter the location
loc = driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[1]/div/div/div/input')
loc.clear()
loc.send_keys("London")

# %%
#choosing frist option
driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[1]/div[1]/div/div[2]/div[4]/div/div[2]/div/div[5]/button').click()

# %%
# Scrapping required details: 
#scraping hostel name, distance from city centre, ratings, total reviews, overall reviews, 
#privates from price, dorms from price, facilities and property description.

#Creating Empty Lists
Name = []
Distance = []
Rating = []
Reviews = []
Overall = []
Privates = []
Dorms = []
Facilities = []
Property = []


# Scraping Names 
N = driver.find_elements(By.XPATH,'//h2[@class="title title-6"]')
for i in N:
    Name.append(i.text)
    
#Scrapping distance from city centre
try:
    D = driver.find_elements(By.XPATH,'//span[@class="description"]')
    for i in D:
        Distance.append(i.text)
except NoSuchElementException:
    Distance.append("-")

#Scrapping ratings
try:
    RT = driver.find_elements(By.XPATH,'//div[@class="rating rating-summary-container big"]')
    for i in RT:
        Rating.append(i.text[:][0:3])
except NoSuchElementException:
    Rating.append("-")
    
#Scrapping total reviews
try:
    RV = driver.find_elements(By.XPATH,'//div[@class="reviews"]')
    for i in RV:
        Reviews.append(i.text)
except NoSuchElementException:
    Reviews.append("-")
    
#Scrapping overall reviews
try:
    O = driver.find_elements(By.XPATH,'//div[@class="keyword"]')
    for i in O:
        Overall.append(i.text)
except NoSuchElementException:
    Overall.append("-")
    
#Scrapping privates from price
P = driver.find_elements(By.XPATH,'//div[@class="price-col"]')[0::2]
for i in P:
    Privates.append(i.text.replace('\n',': ').replace('No Privates Available','NaN'))
       
#Scrapping Dorms from price
P = driver.find_elements(By.XPATH,'//div[@class="price-col"]')[1::2]
for i in P:
    Dorms.append(i.text.replace('\n',': ').replace('No Dorms Available','NaN'))
    
#Scrapping Facilities
try:
    F = driver.find_elements(By.XPATH,'//div[@class="facilities-label facilities"]')
    for i in F:
        Facilities.append(i.text.replace('\n',', '))
except NoSuchElementException:
    Facilities.append("-")
    
#Scrapping property description.
try:
    PD = driver.find_elements(By.XPATH,'//div[@class="rating-factors prop-card-tablet rating-factors small"]')
    for i in PD:
        Property.append(i.text.replace('\n',', '))
except NoSuchElementException:
    Property.append("-")

# %%
print(len(Name),len(Distance),len(Rating),len(Reviews),len(Privates),len(Dorms),len(Facilities),len(Property))
# Out:
# 30 30 30 30 30 30 30 30

# %%
#scraping hostel name, distance from city centre, ratings, total reviews, overall reviews, 
#privates from price, dorms from price, facilities and property description.
# Creating Data Frame 
df = pd.DataFrame({'Hostel name':Name,
                   'Distance from city centre':Distance,
                   'Rating':Rating,
                   'Total reviews':Reviews,
                   'Privates from price':Privates,
                   'Dorms from price':Dorms,
                   'Facilities':Facilities,
                   'Property description':Property})
df
# Out:
#                                 Hostel name         Distance from city centre  \
# 0             Palmers Lodge - Swiss Cottage   Hostel - 6.5km from city centre
# 1                  St Christopher's Village   Hostel - 1.8km from city centre
# 2                             Selina Camden   Hostel - 5.5km from city centre
# 3               Wombat's City Hostel London   Hostel - 3.6km from city centre
# 4                          Generator London     Hostel - 3km from city centre
# 5                      Urbany Hostel London   Hostel - 5.4km from city centre
# 6         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 7                   Smart Camden Inn Hostel   Hostel - 4.4km from city centre
# 8                  YHA London Oxford Street   Hostel - 2.1km from city centre
# 9                        No.8 Seven Sisters     Hostel - 9km from city centre
# 10                       London Backpackers  Hostel - 11.9km from city centre
# 11  Safestay London Kensington Holland Park   Hostel - 5.9km from city centre
# 12                           Phoenix Hostel   Hostel - 4.2km from city centre
# 13              Smart Hyde Park View Hostel     Hostel - 5km from city centre
# 14                  Queen Elizabeth Chelsea   Hostel - 5.7km from city centre
# 15               Smart Hyde Park Inn Hostel     Hostel - 5km from city centre
# 16                         NX London Hostel   Hostel - 6.1km from city centre
# 17                  Hostel One Notting Hill   Hostel - 5.5km from city centre
# 18             St Christopher's Hammersmith   Hostel - 7.5km from city centre
# 19                  St Christopher's Camden   Hostel - 4.3km from city centre
# 20  St Christopher's Inn - Liverpool Street   Hostel - 3.2km from city centre
# 21                   London Waterloo Hostel   Hostel - 0.7km from city centre
# 22      PubLove @ The White Ferry, Victoria   Hostel - 2.4km from city centre
# 23               St Christopher's Greenwich   Hostel - 7.6km from city centre
# 24     PubLove @ The Steam Engine, Waterloo   Hostel - 0.5km from city centre
# 25          St Christopher's Shepherds Bush     Hostel - 7km from city centre
# 26       PubLove @ The Exmouth Arms, Euston   Hostel - 3.4km from city centre
# 27           PubLove @ The Crown, Battersea   Hostel - 4.7km from city centre
# 28                               Park Villa   Hostel - 6.3km from city centre
# 29                  Saint James Backpackers   Hostel - 5.5km from city centre
#
#    Rating        Total reviews          Privates from price  \
# 0     8.8  15463 Total Reviews                          NaN
# 1     8.1  11372 Total Reviews                          NaN
# 2     8.6     33 Total Reviews          Privates From: €399
# 3     9.1  13835 Total Reviews   Privates From: €242.4 €201
# 4     7.7   7050 Total Reviews          Privates From: €112
# 5     9.3    400 Total Reviews          Privates From: €205
# 6     7.0   4396 Total Reviews                          NaN
# 7     8.3   2895 Total Reviews          Privates From: €153
# 8     9.1   4552 Total Reviews          Privates From: €171
# 9     6.2   3816 Total Reviews                          NaN
# 10    8.1   4290 Total Reviews                          NaN
# 11    6.5   1265 Total Reviews                          NaN
# 12    7.6   3661 Total Reviews                          NaN
# 13    8.0   4573 Total Reviews          Privates From: €143
# 14    6.6   3298 Total Reviews                          NaN
# 15    6.9   6332 Total Reviews                          NaN
# 16    7.3   1169 Total Reviews    Privates From: €86.84 €74
# 17    9.1   1414 Total Reviews          Privates From: €195
# 18    7.9   4069 Total Reviews                          NaN
# 19    8.4   3808 Total Reviews                          NaN
# 20    8.8    418 Total Reviews                          NaN
# 21    6.4   2507 Total Reviews                          NaN
# 22    8.1    263 Total Reviews                          NaN
# 23    6.7   3219 Total Reviews                          NaN
# 24    8.4    293 Total Reviews                          NaN
# 25    7.4    696 Total Reviews                          NaN
# 26    7.2   1033 Total Reviews                          NaN
# 27    6.6    255 Total Reviews                          NaN
# 28    7.9    873 Total Reviews                          NaN
# 29    6.6   1814 Total Reviews  Privates From: €105.04 €100
#
#             Dorms from price  \
# 0            Dorms From: €34
# 1     Dorms From: €26.87 €24
# 2   Dorms From: €133.49 €113
# 3     Dorms From: €50.59 €38
# 4            Dorms From: €37
# 5                        NaN
# 6            Dorms From: €31
# 7            Dorms From: €42
# 8                        NaN
# 9            Dorms From: €16
# 10           Dorms From: €27
# 11           Dorms From: €27
# 12     Dorms From: €28.6 €27
# 13                       NaN
# 14           Dorms From: €20
# 15           Dorms From: €26
# 16           Dorms From: €31
# 17           Dorms From: €35
# 18    Dorms From: €25.39 €23
# 19    Dorms From: €32.08 €29
# 20     Dorms From: €41.1 €37
# 21           Dorms From: €37
# 22           Dorms From: €63
# 23    Dorms From: €22.44 €20
# 24           Dorms From: €58
# 25    Dorms From: €23.74 €21
# 26           Dorms From: €59
# 27           Dorms From: €47
# 28           Dorms From: €56
# 29    Dorms From: €35.58 €34
#
#                                            Facilities  \
# 0     Free WiFi, Follows Covid-19 sanitation guidance
# 1     Free WiFi, Follows Covid-19 sanitation guidance
# 2                                           Free WiFi
# 3     Free WiFi, Follows Covid-19 sanitation guidance
# 4     Free WiFi, Follows Covid-19 sanitation guidance
# 5     Free WiFi, Follows Covid-19 sanitation guidance
# 6     Free WiFi, Follows Covid-19 sanitation guidance
# 7     Free WiFi, Follows Covid-19 sanitation guidance
# 8     Free WiFi, Follows Covid-19 sanitation guidance
# 9     Free WiFi, Follows Covid-19 sanitation guidance
# 10  Free WiFi, Free Breakfast, Follows Covid-19 sa...
# 11                                          Free WiFi
# 12    Free WiFi, Follows Covid-19 sanitation guidance
# 13    Free WiFi, Follows Covid-19 sanitation guidance
# 14                                          Free WiFi
# 15                                          Free WiFi
# 16                          Free WiFi, Free Breakfast
# 17                                          Free WiFi
# 18    Free WiFi, Follows Covid-19 sanitation guidance
# 19    Free WiFi, Follows Covid-19 sanitation guidance
# 20    Free WiFi, Follows Covid-19 sanitation guidance
# 21    Free WiFi, Follows Covid-19 sanitation guidance
# 22    Free WiFi, Follows Covid-19 sanitation guidance
# 23    Free WiFi, Follows Covid-19 sanitation guidance
# 24    Free WiFi, Follows Covid-19 sanitation guidance
# 25    Free WiFi, Follows Covid-19 sanitation guidance
# 26    Free WiFi, Follows Covid-19 sanitation guidance
# 27    Free WiFi, Follows Covid-19 sanitation guidance
# 28    Free WiFi, Follows Covid-19 sanitation guidance
# 29  Free WiFi, Free Breakfast, Follows Covid-19 sa...
#
#                                  Property description
# 0   Perfect Location, Superb Staff, Fantastic Clea...
# 1   Perfect Location, Superb Staff, Excellent Clea...
# 2   Perfect Location, Superb Staff, Fantastic Clea...
# 3   Perfect Location, Superb Staff, Fantastic Clea...
# 4   Perfect Location, Marvellous Staff, Awesome Cl...
# 5   Perfect Location, Superb Staff, Fantastic Clea...
# 6   Wonderful Location, Brilliant Staff, Awesome C...
# 7   Perfect Location, Superb Staff, Excellent Clea...
# 8   Perfect Location, Superb Staff, Fantastic Clea...
# 9                    Great Location, Marvellous Staff
# 10  Wonderful Location, Superb Staff, Excellent Cl...
# 11                Wonderful Location, Brilliant Staff
# 12  Perfect Location, Superb Staff, Awesome Cleanl...
# 13  Perfect Location, Superb Staff, Excellent Clea...
# 14               Wonderful Location, Marvellous Staff
# 15                 Perfect Location, Marvellous Staff
# 16  Wonderful Location, Marvellous Staff, Awesome ...
# 17  Perfect Location, Superb Staff, Fantastic Clea...
# 18  Perfect Location, Superb Staff, Excellent Clea...
# 19  Perfect Location, Superb Staff, Excellent Clea...
# 20  Perfect Location, Superb Staff, Fantastic Clea...
# 21                 Perfect Location, Marvellous Staff
# 22  Perfect Location, Superb Staff, Excellent Clea...
# 23  Wonderful Location, Brilliant Staff, Awesome C...
# 24  Perfect Location, Superb Staff, Excellent Clea...
# 25  Perfect Location, Superb Staff, Awesome Cleanl...
# 26  Perfect Location, Marvellous Staff, Awesome Cl...
# 27  Great Location, Brilliant Staff, Good Cleanliness
# 28  Perfect Location, Superb Staff, Excellent Clea...
# 29               Wonderful Location, Marvellous Staff

# %%
driver.close()
